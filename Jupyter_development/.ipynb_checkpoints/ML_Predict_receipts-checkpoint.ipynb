# %%
# !pip3 install pandas
# !pip3 install tensorflow
import pandas as pd
import numpy as np
import tensorflow as tf

# Assuming you have a dataset like the one you provided
# "Date" column should be in datetime format
# "Receipt_Count" column represents the number of receipts received on each day

# Load your dataset


df = pd.read_csv('data_daily.csv')
print(df.head(5))
print(df.columns)
print(df.dtypes)
df['# Date'] = pd.to_datetime(df['# Date'])
df['Month'] = df['# Date'].dt.month
df['Year'] = df['# Date'].dt.year

# Feature engineering
df_agg = df.groupby(['Year', 'Month'], as_index=False)['Receipt_Count'].sum()
df_agg['Prev_Month_Receipts'] = df_agg['Receipt_Count'].shift(1)

# Drop the first row as it will have NaN due to shift
df_agg = df_agg.dropna()

# Model data preparation
X = df_agg[['Prev_Month_Receipts']].values
y = df_agg['Receipt_Count'].values

# Normalize data manually
X_mean, X_std = X.mean(), X.std()
X_normalized = (X - X_mean) / X_std

y_mean, y_std = y.mean(), y.std()
y_normalized = (y - y_mean) / y_std

# Split data into training and testing sets
split_ratio = 0.8
split_index = int(len(X_normalized) * split_ratio)

X_train, X_test = X_normalized[:split_index], X_normalized[split_index:]
y_train, y_test = y_normalized[:split_index], y_normalized[split_index:]

# Model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_dim=1, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer, loss='mean_squared_error')

# Training
model.fit(X_train, y_train, epochs=100, batch_size=8, verbose=2)

# Evaluation
loss = model.evaluate(X_test, y_test)
print(f'Mean Squared Error on Test Set: {loss}')

# Inference for the year 2022
# Assuming new_data is the input for each day's receipts in 2021
# predicted_normalized = model.predict(X_normalized).flatten()
# predicted = predicted_normalized * y_std + y_mean

# # Print the predicted number of receipts for each month of 2022
# print(predicted)


# Generate predictions for the next 12 values
future_values = []

# Use the last sequence of known values to predict the next value

last_sequence = X_normalized[-1]
for _ in range(12):
    prediction = model.predict(last_sequence)
    future_values.append(prediction.flatten())
    last_sequence = prediction.flatten()
   

# Denormalize the predictions
future_values = np.array(future_values) * y_std + y_mean

print(future_values)
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in /opt/homebrew/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: tensorflow-macos==2.14.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.26.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.25.0)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (67.6.1)
# Requirement already satisfied: six>=1.12.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.14.0->tensorflow) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/homebrew/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.2.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
#        # Date  Receipt_Count
# 0  2021-01-01        7564766
# 1  2021-01-02        7455524
# 2  2021-01-03        7095414
# 3  2021-01-04        7666163
# 4  2021-01-05        7771289
# Index(['# Date', 'Receipt_Count'], dtype='object')
# # Date           object
# Receipt_Count     int64
# dtype: object
# Epoch 1/100
# 1/1 - 0s - loss: 0.9887 - 183ms/epoch - 183ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.7651 - 1ms/epoch - 1ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.5848 - 1ms/epoch - 1ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.4453 - 947us/epoch - 947us/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.3426 - 1ms/epoch - 1ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.2746 - 1ms/epoch - 1ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.2380 - 2ms/epoch - 2ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.2295 - 2ms/epoch - 2ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.2422 - 1ms/epoch - 1ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.2658 - 2ms/epoch - 2ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.2880 - 2ms/epoch - 2ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.2995 - 1ms/epoch - 1ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.2986 - 1ms/epoch - 1ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.2868 - 1ms/epoch - 1ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.2702 - 2ms/epoch - 2ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.2524 - 2ms/epoch - 2ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.2387 - 1ms/epoch - 1ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.2318 - 1ms/epoch - 1ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.2320 - 1ms/epoch - 1ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.2366 - 1ms/epoch - 1ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.2418 - 1ms/epoch - 1ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.2445 - 1ms/epoch - 1ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.2448 - 1ms/epoch - 1ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.2421 - 2ms/epoch - 2ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.2374 - 2ms/epoch - 2ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.2323 - 1ms/epoch - 1ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.2280 - 1ms/epoch - 1ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.2254 - 1ms/epoch - 1ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.2241 - 1ms/epoch - 1ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.2240 - 1ms/epoch - 1ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.2242 - 1ms/epoch - 1ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.2246 - 1ms/epoch - 1ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.2247 - 1ms/epoch - 1ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.2248 - 2ms/epoch - 2ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.2241 - 2ms/epoch - 2ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.2228 - 1ms/epoch - 1ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.2213 - 2ms/epoch - 2ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.2198 - 1ms/epoch - 1ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.2184 - 1ms/epoch - 1ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.2174 - 1ms/epoch - 1ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.2169 - 1ms/epoch - 1ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.2167 - 1ms/epoch - 1ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.2164 - 2ms/epoch - 2ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.2161 - 1ms/epoch - 1ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.2154 - 1ms/epoch - 1ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.2143 - 1ms/epoch - 1ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.2129 - 1ms/epoch - 1ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.2116 - 1ms/epoch - 1ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.2102 - 1ms/epoch - 1ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.2088 - 1ms/epoch - 1ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.2076 - 1ms/epoch - 1ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.2066 - 1ms/epoch - 1ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.2056 - 2ms/epoch - 2ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.2045 - 1ms/epoch - 1ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.2035 - 1ms/epoch - 1ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.2029 - 1ms/epoch - 1ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.2019 - 1ms/epoch - 1ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.2006 - 1ms/epoch - 1ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.1998 - 1ms/epoch - 1ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.1989 - 1ms/epoch - 1ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.1980 - 1ms/epoch - 1ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.1970 - 1ms/epoch - 1ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.1961 - 1ms/epoch - 1ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.1951 - 2ms/epoch - 2ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.1941 - 2ms/epoch - 2ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.1930 - 1ms/epoch - 1ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.1919 - 1ms/epoch - 1ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.1906 - 1ms/epoch - 1ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.1898 - 1ms/epoch - 1ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.1885 - 1ms/epoch - 1ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.1875 - 1ms/epoch - 1ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.1865 - 2ms/epoch - 2ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.1855 - 2ms/epoch - 2ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.1846 - 1ms/epoch - 1ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.1836 - 1ms/epoch - 1ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.1827 - 1ms/epoch - 1ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.1816 - 1ms/epoch - 1ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.1803 - 1ms/epoch - 1ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.1792 - 1ms/epoch - 1ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.1778 - 864us/epoch - 864us/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.1770 - 1ms/epoch - 1ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.1760 - 1ms/epoch - 1ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.1749 - 1ms/epoch - 1ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.1736 - 2ms/epoch - 2ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.1729 - 1ms/epoch - 1ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.1717 - 1ms/epoch - 1ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.1700 - 985us/epoch - 985us/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.1688 - 4ms/epoch - 4ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.1685 - 2ms/epoch - 2ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.1671 - 1ms/epoch - 1ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.1653 - 1ms/epoch - 1ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.1643 - 1ms/epoch - 1ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.1630 - 938us/epoch - 938us/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.1622 - 994us/epoch - 994us/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.1608 - 1ms/epoch - 1ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.1591 - 1ms/epoch - 1ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.1579 - 3ms/epoch - 3ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.1567 - 1ms/epoch - 1ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.1554 - 1ms/epoch - 1ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.1543 - 2ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9631
# Mean Squared Error on Test Set: 0.9630613923072815
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# [[2.7561859e+08]
#  [2.7655242e+08]
#  [2.7781453e+08]
#  [2.7952032e+08]
#  [2.8182573e+08]
#  [2.8348128e+08]
#  [2.8377165e+08]
#  [2.8381613e+08]
#  [2.8381974e+08]
#  [2.8381994e+08]
#  [2.8381997e+08]
#  [2.8381997e+08]]

# %%
#method 2

df = pd.read_csv('data_daily.csv')
print(df.head(5))
print(df.columns)
print(df.dtypes)
df['# Date'] = pd.to_datetime(df['# Date'])
df['Month'] = df['# Date'].dt.month
df['Year'] = df['# Date'].dt.year
# Out:
#        # Date  Receipt_Count
# 0  2021-01-01        7564766
# 1  2021-01-02        7455524
# 2  2021-01-03        7095414
# 3  2021-01-04        7666163
# 4  2021-01-05        7771289
# Index(['# Date', 'Receipt_Count'], dtype='object')
# # Date           object
# Receipt_Count     int64
# dtype: object

# %%
print(df.head(5))
# Out:
#       # Date  Receipt_Count  Month  Year
# 0 2021-01-01        7564766      1  2021
# 1 2021-01-02        7455524      1  2021
# 2 2021-01-03        7095414      1  2021
# 3 2021-01-04        7666163      1  2021
# 4 2021-01-05        7771289      1  2021

# %%
# Feature engineering
df_agg = df.groupby(['Year', 'Month'], as_index=False)['Receipt_Count'].sum()
df_agg['Prev_Month_Receipts'] = df_agg['Receipt_Count'].shift(1)
print(df_agg.head(14))
# Out:
#     Year  Month  Receipt_Count  Prev_Month_Receipts
# 0   2021      1      236736687                  NaN
# 1   2021      2      220033460          236736687.0
# 2   2021      3      248608625          220033460.0
# 3   2021      4      250644830          248608625.0
# 4   2021      5      263151748          250644830.0
# 5   2021      6      260656840          263151748.0
# 6   2021      7      274776003          260656840.0
# 7   2021      8      283943231          274776003.0
# 8   2021      9      281146154          283943231.0
# 9   2021     10      295965185          281146154.0
# 10  2021     11      296085162          295965185.0
# 11  2021     12      309948684          296085162.0

# %%
# Drop the first row as it will have NaN due to shift
df_agg = df_agg.dropna()

# Model data preparation
X = df_agg[['Prev_Month_Receipts']].values
y = df_agg['Receipt_Count'].values

# Normalize data manually
X_mean, X_std = X.mean(), X.std()
X_normalized = (X - X_mean) / X_std

y_mean, y_std = y.mean(), y.std()
y_normalized = (y - y_mean) / y_std

# %%
# Inference for the year 2022
# Generate predictions for the next 12 values
sequence_length = 1

# Split data into training and testing sets
split_ratio = 0.8
split_index = int(len(X_normalized) * split_ratio)

X_train, X_test = X_normalized[:split_index], X_normalized[split_index:]
y_train, y_test = y_normalized[:split_index], y_normalized[split_index:]

# Reshape for LSTM input
X_normalized = X_normalized.reshape(X_normalized.shape[0], X_normalized.shape[1], 1)

# Build the LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(500, input_shape=(sequence_length, 1)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')



# Training
model.fit(X_train, y_train, epochs=100, batch_size=8, verbose=2)

# Evaluation
loss = model.evaluate(X_test, y_test)
print(f'Mean Squared Error on Test Set: {loss}')

# Generate predictions for the next 12 values
future_values = []

# Use the last sequence of known values to predict the next value
last_sequence = X_normalized[-1].reshape(1, sequence_length, 1)

for _ in range(12):
    prediction = model.predict(last_sequence)
    future_values.append(prediction.flatten())
    last_sequence = np.roll(last_sequence, -1, axis=1)
    last_sequence[0, -1, 0] = prediction

# Denormalize the predictions
future_values = np.array(future_values) * y_std + y_mean

print(future_values)
# Out:
# Epoch 1/100
# 1/1 - 0s - loss: 0.8488 - 445ms/epoch - 445ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.8267 - 3ms/epoch - 3ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.8051 - 3ms/epoch - 3ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.7840 - 3ms/epoch - 3ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.7635 - 4ms/epoch - 4ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.7434 - 3ms/epoch - 3ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.7238 - 3ms/epoch - 3ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.7047 - 4ms/epoch - 4ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.6859 - 4ms/epoch - 4ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.6676 - 3ms/epoch - 3ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.6497 - 3ms/epoch - 3ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.6322 - 4ms/epoch - 4ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.6150 - 3ms/epoch - 3ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.5982 - 3ms/epoch - 3ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.5818 - 3ms/epoch - 3ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.5657 - 4ms/epoch - 4ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.5500 - 3ms/epoch - 3ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.5347 - 3ms/epoch - 3ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.5197 - 3ms/epoch - 3ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.5052 - 4ms/epoch - 4ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.4910 - 4ms/epoch - 4ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.4772 - 3ms/epoch - 3ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.4639 - 4ms/epoch - 4ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.4510 - 4ms/epoch - 4ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.4385 - 4ms/epoch - 4ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.4266 - 3ms/epoch - 3ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.4151 - 3ms/epoch - 3ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.4042 - 4ms/epoch - 4ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.3938 - 4ms/epoch - 4ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.3839 - 4ms/epoch - 4ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.3746 - 5ms/epoch - 5ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.3659 - 5ms/epoch - 5ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.3577 - 4ms/epoch - 4ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.3502 - 5ms/epoch - 5ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.3432 - 5ms/epoch - 5ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.3368 - 4ms/epoch - 4ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.3310 - 5ms/epoch - 5ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.3256 - 5ms/epoch - 5ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.3208 - 4ms/epoch - 4ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.3165 - 5ms/epoch - 5ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.3126 - 5ms/epoch - 5ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.3091 - 4ms/epoch - 4ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.3060 - 3ms/epoch - 3ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.3031 - 4ms/epoch - 4ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.3005 - 5ms/epoch - 5ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.2981 - 4ms/epoch - 4ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.2958 - 4ms/epoch - 4ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.2937 - 5ms/epoch - 5ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.2916 - 4ms/epoch - 4ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.2896 - 3ms/epoch - 3ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.2876 - 4ms/epoch - 4ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.2856 - 5ms/epoch - 5ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.2837 - 3ms/epoch - 3ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.2817 - 4ms/epoch - 4ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.2797 - 4ms/epoch - 4ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.2778 - 5ms/epoch - 5ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.2758 - 4ms/epoch - 4ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.2739 - 4ms/epoch - 4ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.2720 - 5ms/epoch - 5ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.2702 - 3ms/epoch - 3ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.2684 - 4ms/epoch - 4ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.2666 - 5ms/epoch - 5ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.2650 - 4ms/epoch - 4ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.2634 - 4ms/epoch - 4ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.2619 - 3ms/epoch - 3ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.2605 - 5ms/epoch - 5ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.2592 - 4ms/epoch - 4ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.2579 - 4ms/epoch - 4ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.2568 - 5ms/epoch - 5ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.2558 - 4ms/epoch - 4ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.2548 - 3ms/epoch - 3ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.2539 - 3ms/epoch - 3ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.2531 - 3ms/epoch - 3ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.2524 - 5ms/epoch - 5ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.2517 - 4ms/epoch - 4ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.2511 - 3ms/epoch - 3ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.2505 - 4ms/epoch - 4ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.2495 - 7ms/epoch - 7ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.2491 - 6ms/epoch - 6ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.2487 - 4ms/epoch - 4ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.2483 - 3ms/epoch - 3ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.2479 - 5ms/epoch - 5ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.2476 - 4ms/epoch - 4ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.2473 - 4ms/epoch - 4ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.2470 - 6ms/epoch - 6ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.2467 - 4ms/epoch - 4ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.2465 - 4ms/epoch - 4ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.2463 - 4ms/epoch - 4ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.2460 - 5ms/epoch - 5ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.2458 - 3ms/epoch - 3ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.2456 - 3ms/epoch - 3ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.2454 - 4ms/epoch - 4ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.2453 - 3ms/epoch - 3ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.2451 - 3ms/epoch - 3ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.2449 - 3ms/epoch - 3ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.2448 - 3ms/epoch - 3ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.2446 - 4ms/epoch - 4ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.2445 - 3ms/epoch - 3ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.2444 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 144ms/step - loss: 0.3016
# Mean Squared Error on Test Set: 0.3015633523464203
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# /var/folders/6w/1czj28vj3_q0hl9l50q3p0m80000gn/T/ipykernel_79330/3741129475.py:42: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_sequence[0, -1, 0] = prediction
# 1/1 [==============================] - 0s 8ms/step
# [[2.9216653e+08]
#  [2.8343405e+08]
#  [2.7720746e+08]
#  [2.7269818e+08]
#  [2.6939962e+08]
#  [2.6697045e+08]
#  [2.6517322e+08]
#  [2.6383920e+08]
#  [2.6284674e+08]
#  [2.6210714e+08]
#  [2.6155531e+08]
#  [2.6114322e+08]]

# %%
df_agg['Receipt_Count']
# Out:
# 1     220033460
# 2     248608625
# 3     250644830
# 4     263151748
# 5     260656840
# 6     274776003
# 7     283943231
# 8     281146154
# 9     295965185
# 10    296085162
# 11    309948684
# Name: Receipt_Count, dtype: int64

# %%
#method 3: using difference in values

# %%
import numpy as np
import pandas as pd
import tensorflow as tf


# Provided data
df = pd.read_csv('data_daily.csv')
print(df.head(5))
print(df.columns)
print(df.dtypes)
df['# Date'] = pd.to_datetime(df['# Date'])
df['Month'] = df['# Date'].dt.month
df['Year'] = df['# Date'].dt.year

# Feature engineering
df_agg = df.groupby(['Year', 'Month'], as_index=False)['Receipt_Count'].sum()


# Take the difference between consecutive values
df_agg['Diff_Values'] = df_agg['Receipt_Count'].diff().fillna(0)

# Create input and target data for training
X_train = df_agg['Diff_Values'][:-1].values.reshape(-1, 1, 1)
y_train = df_agg['Diff_Values'][1:].values.reshape(-1, 1)

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_dim=1, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer, loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# Generate predictions for the next 12 values
X_pred = df_agg['Diff_Values'].values[-1].reshape(1, 1, 1)
y_pred_diff = []
for _ in range(12):
    pred_diff = model.predict(X_pred)
    y_pred_diff.append(pred_diff.flatten())
    X_pred = pred_diff.reshape(1, 1, 1)

print("1:",df_agg['Diff_Values'].values)
print("2:", y_pred_diff)
res = np.concatenate(y_pred_diff)
print("3:", res)
# Cumulatively sum the differences to obtain predictions for the original time series
# y_pred_cumsum = np.cumsum(np.concatenate([df_agg['Diff_Values'].values, res]))
                                          
# print(y_pred_cumsum)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
#        # Date  Receipt_Count
# 0  2021-01-01        7564766
# 1  2021-01-02        7455524
# 2  2021-01-03        7095414
# 3  2021-01-04        7666163
# 4  2021-01-05        7771289
# Index(['# Date', 'Receipt_Count'], dtype='object')
# # Date           object
# Receipt_Count     int64
# dtype: object
# Epoch 1/100
# 11/11 - 0s - loss: 188173086883840.0000 - 128ms/epoch - 12ms/step
# Epoch 2/100
# 11/11 - 0s - loss: 146056939569152.0000 - 5ms/epoch - 453us/step
# Epoch 3/100
# 11/11 - 0s - loss: 115698156175360.0000 - 5ms/epoch - 439us/step
# Epoch 4/100
# 11/11 - 0s - loss: 104157176397824.0000 - 5ms/epoch - 462us/step
# Epoch 5/100
# 11/11 - 0s - loss: 86831446097920.0000 - 6ms/epoch - 526us/step
# Epoch 6/100
# 11/11 - 0s - loss: 84096885719040.0000 - 5ms/epoch - 467us/step
# Epoch 7/100
# 11/11 - 0s - loss: 83738222395392.0000 - 4ms/epoch - 386us/step
# Epoch 8/100
# 11/11 - 0s - loss: 83478846636032.0000 - 5ms/epoch - 494us/step
# Epoch 9/100
# 11/11 - 0s - loss: 83044157358080.0000 - 4ms/epoch - 391us/step
# Epoch 10/100
# 11/11 - 0s - loss: 85975380262912.0000 - 4ms/epoch - 394us/step
# Epoch 11/100
# 11/11 - 0s - loss: 85314559279104.0000 - 5ms/epoch - 431us/step
# Epoch 12/100
# 11/11 - 0s - loss: 84117899182080.0000 - 5ms/epoch - 412us/step
# Epoch 13/100
# 11/11 - 0s - loss: 84289714651136.0000 - 4ms/epoch - 382us/step
# Epoch 14/100
# 11/11 - 0s - loss: 86243689889792.0000 - 5ms/epoch - 457us/step
# Epoch 15/100
# 11/11 - 0s - loss: 84542731845632.0000 - 4ms/epoch - 391us/step
# Epoch 16/100
# 11/11 - 0s - loss: 82698286661632.0000 - 4ms/epoch - 387us/step
# Epoch 17/100
# 11/11 - 0s - loss: 82904914853888.0000 - 5ms/epoch - 410us/step
# Epoch 18/100
# 11/11 - 0s - loss: 82890444505088.0000 - 5ms/epoch - 461us/step
# Epoch 19/100
# 11/11 - 0s - loss: 82861562527744.0000 - 4ms/epoch - 389us/step
# Epoch 20/100
# 11/11 - 0s - loss: 83292116221952.0000 - 4ms/epoch - 401us/step
# Epoch 21/100
# 11/11 - 0s - loss: 83705943031808.0000 - 5ms/epoch - 448us/step
# Epoch 22/100
# 11/11 - 0s - loss: 82954030153728.0000 - 4ms/epoch - 397us/step
# Epoch 23/100
# 11/11 - 0s - loss: 82662979010560.0000 - 4ms/epoch - 379us/step
# Epoch 24/100
# 11/11 - 0s - loss: 83608081530880.0000 - 5ms/epoch - 448us/step
# Epoch 25/100
# 11/11 - 0s - loss: 82564538695680.0000 - 4ms/epoch - 387us/step
# Epoch 26/100
# 11/11 - 0s - loss: 82594754461696.0000 - 4ms/epoch - 393us/step
# Epoch 27/100
# 11/11 - 0s - loss: 82929585750016.0000 - 5ms/epoch - 412us/step
# Epoch 28/100
# 11/11 - 0s - loss: 83678596169728.0000 - 5ms/epoch - 428us/step
# Epoch 29/100
# 11/11 - 0s - loss: 82830491123712.0000 - 4ms/epoch - 402us/step
# Epoch 30/100
# 11/11 - 0s - loss: 82877299556352.0000 - 4ms/epoch - 382us/step
# Epoch 31/100
# 11/11 - 0s - loss: 84416978223104.0000 - 5ms/epoch - 473us/step
# Epoch 32/100
# 11/11 - 0s - loss: 81550985134080.0000 - 4ms/epoch - 382us/step
# Epoch 33/100
# 11/11 - 0s - loss: 83946863853568.0000 - 4ms/epoch - 396us/step
# Epoch 34/100
# 11/11 - 0s - loss: 83710841978880.0000 - 5ms/epoch - 443us/step
# Epoch 35/100
# 11/11 - 0s - loss: 84005122736128.0000 - 5ms/epoch - 412us/step
# Epoch 36/100
# 11/11 - 0s - loss: 82830105247744.0000 - 4ms/epoch - 390us/step
# Epoch 37/100
# 11/11 - 0s - loss: 82386096226304.0000 - 5ms/epoch - 449us/step
# Epoch 38/100
# 11/11 - 0s - loss: 82825550233600.0000 - 5ms/epoch - 412us/step
# Epoch 39/100
# 11/11 - 0s - loss: 83697738973184.0000 - 4ms/epoch - 375us/step
# Epoch 40/100
# 11/11 - 0s - loss: 82853274583040.0000 - 4ms/epoch - 385us/step
# Epoch 41/100
# 11/11 - 0s - loss: 82620138389504.0000 - 5ms/epoch - 444us/step
# Epoch 42/100
# 11/11 - 0s - loss: 83023689154560.0000 - 4ms/epoch - 402us/step
# Epoch 43/100
# 11/11 - 0s - loss: 82595073228800.0000 - 4ms/epoch - 375us/step
# Epoch 44/100
# 11/11 - 0s - loss: 82525414227968.0000 - 5ms/epoch - 425us/step
# Epoch 45/100
# 11/11 - 0s - loss: 83134854987776.0000 - 5ms/epoch - 425us/step
# Epoch 46/100
# 11/11 - 0s - loss: 83087694233600.0000 - 4ms/epoch - 398us/step
# Epoch 47/100
# 11/11 - 0s - loss: 83523281092608.0000 - 4ms/epoch - 386us/step
# Epoch 48/100
# 11/11 - 0s - loss: 82863047311360.0000 - 5ms/epoch - 455us/step
# Epoch 49/100
# 11/11 - 0s - loss: 81952480690176.0000 - 5ms/epoch - 433us/step
# Epoch 50/100
# 11/11 - 0s - loss: 83982020509696.0000 - 4ms/epoch - 391us/step
# Epoch 51/100
# 11/11 - 0s - loss: 83065254707200.0000 - 5ms/epoch - 439us/step
# Epoch 52/100
# 11/11 - 0s - loss: 82463372083200.0000 - 5ms/epoch - 415us/step
# Epoch 53/100
# 11/11 - 0s - loss: 82858198695936.0000 - 4ms/epoch - 386us/step
# Epoch 54/100
# 11/11 - 0s - loss: 82788195762176.0000 - 5ms/epoch - 478us/step
# Epoch 55/100
# 11/11 - 0s - loss: 83126600597504.0000 - 5ms/epoch - 419us/step
# Epoch 56/100
# 11/11 - 0s - loss: 84464835231744.0000 - 4ms/epoch - 379us/step
# Epoch 57/100
# 11/11 - 0s - loss: 81691930525696.0000 - 5ms/epoch - 416us/step
# Epoch 58/100
# 11/11 - 0s - loss: 84200073986048.0000 - 5ms/epoch - 427us/step
# Epoch 59/100
# 11/11 - 0s - loss: 83893789130752.0000 - 5ms/epoch - 421us/step
# Epoch 60/100
# 11/11 - 0s - loss: 82799126118400.0000 - 4ms/epoch - 381us/step
# Epoch 61/100
# 11/11 - 0s - loss: 83279835299840.0000 - 6ms/epoch - 526us/step
# Epoch 62/100
# 11/11 - 0s - loss: 83773966254080.0000 - 5ms/epoch - 439us/step
# Epoch 63/100
# 11/11 - 0s - loss: 83495992950784.0000 - 4ms/epoch - 407us/step
# Epoch 64/100
# 11/11 - 0s - loss: 84308723236864.0000 - 5ms/epoch - 471us/step
# Epoch 65/100
# 11/11 - 0s - loss: 83575307239424.0000 - 5ms/epoch - 437us/step
# Epoch 66/100
# 11/11 - 0s - loss: 82624366247936.0000 - 4ms/epoch - 390us/step
# Epoch 67/100
# 11/11 - 0s - loss: 82736303833088.0000 - 5ms/epoch - 463us/step
# Epoch 68/100
# 11/11 - 0s - loss: 82098425692160.0000 - 5ms/epoch - 442us/step
# Epoch 69/100
# 11/11 - 0s - loss: 83088927358976.0000 - 4ms/epoch - 382us/step
# Epoch 70/100
# 11/11 - 0s - loss: 83348655439872.0000 - 5ms/epoch - 455us/step
# Epoch 71/100
# 11/11 - 0s - loss: 82655840305152.0000 - 5ms/epoch - 428us/step
# Epoch 72/100
# 11/11 - 0s - loss: 83236248092672.0000 - 4ms/epoch - 406us/step
# Epoch 73/100
# 11/11 - 0s - loss: 82580107952128.0000 - 12ms/epoch - 1ms/step
# Epoch 74/100
# 11/11 - 0s - loss: 83061832155136.0000 - 6ms/epoch - 559us/step
# Epoch 75/100
# 11/11 - 0s - loss: 83126936141824.0000 - 6ms/epoch - 507us/step
# Epoch 76/100
# 11/11 - 0s - loss: 82989304250368.0000 - 5ms/epoch - 413us/step
# Epoch 77/100
# 11/11 - 0s - loss: 82533878333440.0000 - 4ms/epoch - 405us/step
# Epoch 78/100
# 11/11 - 0s - loss: 83070900240384.0000 - 5ms/epoch - 481us/step
# Epoch 79/100
# 11/11 - 0s - loss: 83654587973632.0000 - 4ms/epoch - 400us/step
# Epoch 80/100
# 11/11 - 0s - loss: 82317896843264.0000 - 5ms/epoch - 412us/step
# Epoch 81/100
# 11/11 - 0s - loss: 82538383015936.0000 - 5ms/epoch - 463us/step
# Epoch 82/100
# 11/11 - 0s - loss: 82455998496768.0000 - 5ms/epoch - 409us/step
# Epoch 83/100
# 11/11 - 0s - loss: 82803186204672.0000 - 5ms/epoch - 411us/step
# Epoch 84/100
# 11/11 - 0s - loss: 82626840887296.0000 - 5ms/epoch - 497us/step
# Epoch 85/100
# 11/11 - 0s - loss: 84953614254080.0000 - 5ms/epoch - 412us/step
# Epoch 86/100
# 11/11 - 0s - loss: 82281372844032.0000 - 5ms/epoch - 411us/step
# Epoch 87/100
# 11/11 - 0s - loss: 82930298781696.0000 - 5ms/epoch - 462us/step
# Epoch 88/100
# 11/11 - 0s - loss: 82635531485184.0000 - 5ms/epoch - 422us/step
# Epoch 89/100
# 11/11 - 0s - loss: 83382889349120.0000 - 4ms/epoch - 402us/step
# Epoch 90/100
# 11/11 - 0s - loss: 82709955215360.0000 - 5ms/epoch - 437us/step
# Epoch 91/100
# 11/11 - 0s - loss: 82360032821248.0000 - 5ms/epoch - 462us/step
# Epoch 92/100
# 11/11 - 0s - loss: 82752477069312.0000 - 4ms/epoch - 385us/step
# Epoch 93/100
# 11/11 - 0s - loss: 82476315705344.0000 - 5ms/epoch - 470us/step
# Epoch 94/100
# 11/11 - 0s - loss: 84084705460224.0000 - 5ms/epoch - 441us/step
# Epoch 95/100
# 11/11 - 0s - loss: 85126520242176.0000 - 4ms/epoch - 379us/step
# Epoch 96/100
# 11/11 - 0s - loss: 83798611984384.0000 - 4ms/epoch - 397us/step
# Epoch 97/100
# 11/11 - 0s - loss: 82833074814976.0000 - 6ms/epoch - 524us/step
# Epoch 98/100
# 11/11 - 0s - loss: 82608889266176.0000 - 4ms/epoch - 403us/step
# Epoch 99/100
# 11/11 - 0s - loss: 82567399211008.0000 - 5ms/epoch - 414us/step
# Epoch 100/100
# 11/11 - 0s - loss: 82635976081408.0000 - 5ms/epoch - 489us/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1: [        0. -16703227.  28575165.   2036205.  12506918.  -2494908.
#   14119163.   9167228.  -2797077.  14819031.    119977.  13863522.]
# 2: [array([1406708.], dtype=float32), array([142741.28], dtype=float32), array([14489.247], dtype=float32), array([1475.7804], dtype=float32), array([155.32277], dtype=float32), array([21.297869], dtype=float32), array([7.053296], dtype=float32), array([4.583849], dtype=float32), array([4.155744], dtype=float32), array([4.0815277], dtype=float32), array([4.0686617], dtype=float32), array([4.066431], dtype=float32)]
# 3: [1.4067080e+06 1.4274128e+05 1.4489247e+04 1.4757804e+03 1.5532277e+02
#  2.1297869e+01 7.0532961e+00 4.5838490e+00 4.1557441e+00 4.0815277e+00
#  4.0686617e+00 4.0664310e+00]
# [        0.         -16703227.          11871938.
#   13908143.          26415061.          23920153.
#   38039316.          47206544.          44409467.
#   59228498.          59348475.          73211997.
#   74618705.          74761446.28125     74775935.52832031
#   74777411.30871582  74777566.63148499  74777587.92935371
#   74777594.9826498   74777599.56649876  74777603.72224283
#   74777607.80377054  74777611.87243223  74777615.93886328]

# %%
predictions = []
dec2021_val = 309948684
i = 1
j = 1
fir = 309948684 + res[0]
predictions.append(fir)
while(i<12 and j<12):
    predictions.append(predictions[i-1] + y_pred_cumsum[j])
    i+=1
    j+=1
print(predictions)
# Out:
# [311355392.0, 294652165.0, 306524103.0, 320432246.0, 346847307.0, 370767460.0, 408806776.0, 456013320.0, 500422787.0, 559651285.0, 618999760.0, 692211757.0]
